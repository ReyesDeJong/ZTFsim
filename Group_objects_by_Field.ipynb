# %%
#python 2 and 3 comptibility
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import json
import io
import gzip
import base64
from astropy.io import fits
import matplotlib.pylab as plt
import pickle as pkl
import numpy as np
import sys 
import os
# %matplotlib inline

PATH_TO_PROJECT = os.path.abspath(
    os.path.join(os.path.dirname('__file__'), ''))
sys.path.append(PATH_TO_PROJECT)
sys.path.append(os.path.join(PATH_TO_PROJECT,'..'))

data_path = '../AlerceDHtest/datasets/ZTF'

path = data_path+'/broker_reals.json'
with open(path, "r") as f:
        dataset = json.load(f)

# %%
#print object ids
#for alert in dataset["query_result"]:
#    print(alert["objectId"])

# %%
#build dict by alert id
alerts = {}
passbands = ["g", "r", "i"]
for alert in dataset["query_result"]:
    dict_in_stamp = {'science_stamp':None, 'filter': None, 'fwhm': None, 'mjd': None, 'field': None, 'object_id': None}
    #get params to save in dict
    dict_in_stamp['filter'] = passbands[alert["candidate"]["fid"]-1]
    dict_in_stamp['fwhm'] = alert["candidate"]["fwhm"]
    dict_in_stamp['mjd'] = alert["candidate"]["jd"]
    dict_in_stamp['object_id'] = alert['objectId']
    dict_in_stamp['field'] = alert["candidate"]["field"]
    dict_in_stamp['_id'] = alert["_id"]
    #other observation conditions
    dict_in_stamp['exp_time'] = 30#alert["candidate"]["exptime"]
    dict_in_stamp['limmag3'] = None
    dict_in_stamp['limmag5'] = alert["candidate"]["diffmaglim"]
    dict_in_stamp['obs_days'] = alert["candidate"]["jd"]
    dict_in_stamp['seeing'] = alert["candidate"]["fwhm"]
    dict_in_stamp['sky_brightness'] = None #Needs to be calculated from science stamp
    dict_in_stamp['zero_point'] =  1.0 #We dont have it but a constant is enough
    #stamps
    stamp = alert['cutoutScience']['stampData']
    stamp = base64.b64decode(stamp["$binary"].encode())
    with gzip.open(io.BytesIO(stamp), 'rb') as f:
        with fits.open(io.BytesIO(f.read())) as hdul:
            img = hdul[0].data
    dict_in_stamp['science_stamp'] = img
    
    stamp_id = alert["_id"]
    
    if stamp_id in alerts.keys():
        print(stamp_id)
        continue
    else:
        alerts[stamp_id] = dict_in_stamp

# %%
def createCircularMask(h, w, center=None, radius=None):

    if center is None: # use the middle of the image
        center = [int(w/2), int(h/2)]
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])
    radius = np.round(radius)
    
    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius
    return mask

# %%
# add masked sky and sky array to dicts
n_sigmas = 4

#check if values are already in dict, to avoid second innecesarry runs
if 'masked_sky' not in alerts[list(alerts.keys())[0]].keys():
    for alert_id in alerts:
        alert = alerts[alert_id] 
        fw = alert['fwhm']
        mask = ~createCircularMask(alert['science_stamp'].shape[0], alert['science_stamp'].shape[1], radius=n_sigmas*(fw/2.35482))
        masked_sky = alert['science_stamp']*mask
        alert['masked_sky'] = masked_sky

        sky_pixels_cord = np.argwhere(mask==True)
        sky_pixels = np.array([masked_sky[cord[0],cord[1]] for cord in list(sky_pixels_cord)])
        alert['sky_pixel_values'] = sky_pixels

# %%
#class to filter sky without considering nans
class Sky_filter:

    def __init__(self, sky_pixels, n_sigma=2, filter_iterations=5):
        
        self.n = n_sigma
        self.sigmas = np.empty((0))
        self.n_sigmas = np.empty((0))
        self.sky_pixels = sky_pixels[np.logical_not(np.isnan(sky_pixels))]      
        
    def get_n_sigma(self, sky_pixels):
        sigma = np.std(sky_pixels)
        #print(np.mean(sky_pixels))
        #print(np.mean(sky_pixels)+sigma)
        n_sigma = np.mean(sky_pixels)+self.n*sigma
        self.sigmas = np.append(self.sigmas,np.mean(sky_pixels)+sigma)
        self.n_sigmas = np.append(self.n_sigmas,n_sigma)
        return n_sigma
    
    def filter_sky_once(self):
        last_filtered_sky = self.filtered_sky['it%i'%(len(list(self.filtered_sky.keys()))-1)]
        n_sigma = self.get_n_sigma(last_filtered_sky)
        pixels_over_sigma = np.abs(last_filtered_sky)>n_sigma
        pixels_over_std_cord = np.argwhere(pixels_over_sigma==True)
        #print(pixels_over_std_cord)
        new_filtered_sky = np.delete(last_filtered_sky, pixels_over_std_cord)
        self.filtered_sky['it%i'%len(list(self.filtered_sky.keys()))] = new_filtered_sky
        
    def iterative_filtering(self, iterations):
        #print(self.sky_pixels.shape)
        if np.isnan(self.sky_pixels).any():
            return None
            
        self.sigmas = np.empty((0))
        self.n_sigmas = np.empty((0))
        self.filtered_sky = {'it0':self.sky_pixels}
        for i in range(iterations):
            self.filter_sky_once()
        return self.filtered_sky

    def check_availability(self, array, idx):
        array = np.array(array)
        if array.shape[0]-1<idx:
            check_nans = self.iterative_filtering(idx+1)
        if check_nans is None:
            raise ValueError('nans in sky pixels')
            
    def plot_array(self, array):
        array = np.array(array)
        x = np.arange(0, array.shape[0])
        plt.plot(x,array)
            
    def plot_filtered_sky_sigmas(self, idx=0, x_pos=32, y_pos=32):
        self.check_availability(self.n_sigmas, idx)
        
        #plt.figure(figsize=(12,12))
        line = np.arange(0,self.sky_pixels.shape[0])
        n_sigma_line = np.full(self.sky_pixels.shape[0], self.n_sigmas[idx])
        mean = np.full(self.sky_pixels.shape[0], np.mean(self.sky_pixels))
        plt.scatter(line, self.sky_pixels)
        #plt.lim(np.min(self.sky_pixels),np.max(self.sky_pixels))
        plt.plot(line, n_sigma_line, color='black', label='sigma')
        plt.plot(line, mean, '--', color='black', label='mean')
        #print(self.sky_pixels)
        #print(self.sky_pixels.shape)
        plt.title(r'non-filtered $\sigma$[%f], max: %f'%(self.n_sigmas[idx].round(decimals=3), np.max(self.sky_pixels)))
        plt.legend()
        plt.show()

        filtered_sky = self.filtered_sky['it%i'%idx]
        line = np.arange(0,filtered_sky.shape[0])
        n_sigma_line = np.full(filtered_sky.shape[0], self.n_sigmas[idx])
        mean = np.full(filtered_sky.shape[0], np.mean(filtered_sky))
        plt.scatter(line, filtered_sky)
        plt.plot(line, n_sigma_line, color='black', label='sigma')
        plt.plot(line, mean, '--', color='black', label='mean')
        plt.title(r'filtered $\sigma$['+str(idx)+r']: '+str(self.n_sigmas[idx].round(decimals=3)))
        plt.legend()
        plt.show()
        
        self.plot_array(self.n_sigmas)
        plt.title(r'$\sigma$´s progretions')
        plt.show()

# %%
# add filtered sky (after filter_iterations iterations) to dict
filter_iterations = 10

#check if values are already in dict, to avoid second innecesarry runs
if 'filtered_sky_pixel_values' not in alerts[list(alerts.keys())[0]].keys():
    #i=0
    for alert_id in alerts:
        #print(i)
        #i+=1
        alert = alerts[alert_id] 
        sky_values = alert['sky_pixel_values']
        sky_filter = Sky_filter(sky_values)
        filtered_sky = sky_filter.iterative_filtering(iterations=filter_iterations)
        #get last iteration filtered sky
        last_iteration_filtered_sky = filtered_sky[list(filtered_sky.keys())[-1]]
        mean_sky_value = np.mean(last_iteration_filtered_sky)
        #add data to dict
        alert['filtered_sky_pixel_values'] = last_iteration_filtered_sky
        alert['sky_value'] = mean_sky_value

# %%
alerts[alert_id].keys()
# Out:
# dict_keys(['science_stamp', 'filter', 'fwhm', 'mjd', 'field', 'object_id', '_id', 'exp_time', 'limmag3', 'limmag5', 'obs_days', 'seeing', 'sky_brightness', 'zero_point', 'masked_sky', 'sky_pixel_values', 'filtered_sky_pixel_values', 'sky_value'])

# %% [markdown]
# # Filter alerts that have less than N_ALERTS_IN_MJD

# %%
#all mjds
all_mjd = [alerts[alert_id]['mjd'] for alert_id in alerts]

# %%
#count mjds and generate dict mjd/count_mjd
#TODO: add frequency to dict
from collections import Counter
mjd_group_dict = Counter(all_mjd)
#print(Counter(all_mjd).keys()) # equals to list(set(words))
#print(Counter(all_mjd).values()) # counts the elements' frequency

# %%
#filter alerts that have less than 10 mjd freq
N_ALERTS_IN_MJD = 20
filtered_alerts = {}

for alert_id in alerts:
    alert_mjd = alerts[alert_id]['mjd']
    if mjd_group_dict[alert_mjd]>=N_ALERTS_IN_MJD:
        filtered_alerts[alert_id] = alerts[alert_id]

# %%
filtered_alerts[alert_id].keys()
# Out:
# dict_keys(['science_stamp', 'filter', 'fwhm', 'mjd', 'field', 'object_id', '_id', 'exp_time', 'limmag3', 'limmag5', 'obs_days', 'seeing', 'sky_brightness', 'zero_point', 'masked_sky', 'sky_pixel_values', 'filtered_sky_pixel_values', 'sky_value'])

# %% [markdown]
# # Group alerts by field (every object is considered as a diferrent field)

# %%
all_objectsId = [filtered_alerts[alert_id]['object_id'] for alert_id in filtered_alerts]
objectId_uniques = np.unique(all_objectsId)

# %%
#name field
field_objectId_dict = {}
for i, objectId in enumerate(objectId_uniques):
    field_objectId_dict['Field%s' % str(i+1).zfill(2)] = objectId

# %%
#create dict of fields as in https://github.com/rodrigcd/HiTS_simulations
camera_obs_cond = {}
camera_obs_cond["obs_conditions"] = {}
for field in field_objectId_dict.keys():
    camera_obs_cond["obs_conditions"][field] = []
    for alert_id in filtered_alerts:
        if filtered_alerts[alert_id]['object_id'] == field_objectId_dict[field]:
            camera_obs_cond["obs_conditions"][field].append(filtered_alerts[alert_id])

# %%
camera_obs_cond["obs_conditions"]
# Out:
# {'Field01': [{'science_stamp': array([[123.20407 , 127.22096 , 117.12474 , ..., 128.8524  , 111.45215 ,
#            125.553665],
#           [122.64505 , 115.096375, 121.96744 , ..., 116.10672 , 119.21034 ,
#            125.684555],
#           [125.267944, 119.76524 , 122.513824, ..., 129.42937 , 119.66519 ,
#            120.97003 ],
#           ...,
#           [138.09692 , 153.87723 , 139.80548 , ..., 115.56909 , 115.763115,
#            126.22919 ],
#           [134.58777 , 125.77505 , 120.116066, ..., 115.15088 , 119.28728 ,
#            118.001854],
#           [120.917816, 131.72041 , 120.86147 , ..., 123.81089 , 118.3566  ,
#            128.24765 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.609999895095825,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfe',
#    '_id': '493392771315015067_ZTF18aarwvfe',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.87923812866211,
#    'obs_days': 2458247.8927778,
#    'seeing': 2.609999895095825,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[123.20407 , 127.22096 , 117.12474 , ..., 128.8524  , 111.45215 ,
#            125.553665],
#           [122.64505 , 115.096375, 121.96744 , ..., 116.10672 , 119.21034 ,
#            125.684555],
#           [125.267944, 119.76524 , 122.513824, ..., 129.42937 , 119.66519 ,
#            120.97003 ],
#           ...,
#           [138.09692 , 153.87723 , 139.80548 , ..., 115.56909 , 115.763115,
#            126.22919 ],
#           [134.58777 , 125.77505 , 120.116066, ..., 115.15088 , 119.28728 ,
#            118.001854],
#           [120.917816, 131.72041 , 120.86147 , ..., 123.81089 , 118.3566  ,
#            128.24765 ]], dtype=float32),
#    'sky_pixel_values': array([123.20407, 127.22096, 117.12474, ..., 123.81089, 118.3566 ,
#           128.24765], dtype=float32),
#    'filtered_sky_pixel_values': array([123.20407, 127.22096, 117.12474, ..., 123.81089, 118.3566 ,
#           128.24765], dtype=float32),
#    'sky_value': 122.06652},
#   {'science_stamp': array([[127.242676, 113.57087 , 125.202194, ..., 123.42563 , 130.75668 ,
#            124.881546],
#           [118.157104, 121.49902 , 118.08449 , ..., 121.50943 , 118.336914,
#            122.6673  ],
#           [129.4193  , 123.38612 , 115.97984 , ..., 126.540146, 123.78204 ,
#            129.32683 ],
#           ...,
#           [135.48427 , 131.69357 , 128.3364  , ..., 114.39723 , 115.445045,
#            119.786026],
#           [120.0496  , 121.71587 , 120.860115, ..., 123.14886 , 123.00113 ,
#            122.716225],
#           [120.26312 , 126.27754 , 120.29566 , ..., 118.30515 , 122.663864,
#            115.99271 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.119999885559082,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfe',
#    '_id': '498440401315015056_ZTF18aarwvfe',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.955190658569336,
#    'obs_days': 2458252.9404051,
#    'seeing': 3.119999885559082,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[127.242676, 113.57087 , 125.202194, ..., 123.42563 , 130.75668 ,
#            124.881546],
#           [118.157104, 121.49902 , 118.08449 , ..., 121.50943 , 118.336914,
#            122.6673  ],
#           [129.4193  , 123.38612 , 115.97984 , ..., 126.540146, 123.78204 ,
#            129.32683 ],
#           ...,
#           [135.48427 , 131.69357 , 128.3364  , ..., 114.39723 , 115.445045,
#            119.786026],
#           [120.0496  , 121.71587 , 120.860115, ..., 123.14886 , 123.00113 ,
#            122.716225],
#           [120.26312 , 126.27754 , 120.29566 , ..., 118.30515 , 122.663864,
#            115.99271 ]], dtype=float32),
#    'sky_pixel_values': array([127.242676, 113.57087 , 125.202194, ..., 118.30515 , 122.663864,
#           115.99271 ], dtype=float32),
#    'filtered_sky_pixel_values': array([127.242676, 113.57087 , 125.202194, ..., 118.30515 , 122.663864,
#           115.99271 ], dtype=float32),
#    'sky_value': 121.95491},
#   {'science_stamp': array([[125.39441 , 119.12848 , 119.85814 , ..., 116.66223 , 123.87539 ,
#                   nan],
#           [120.07695 , 122.403275, 123.58795 , ..., 127.35673 , 121.425644,
#                   nan],
#           [117.477905, 124.124466, 126.592224, ..., 128.18027 , 115.513504,
#                   nan],
#           ...,
#           [126.00398 , 130.90143 , 130.54263 , ..., 122.50885 , 121.133606,
#            118.98976 ],
#           [130.01434 , 118.703445, 122.392136, ..., 129.69894 , 121.73154 ,
#            128.19768 ],
#           [119.43631 , 116.60925 , 121.48587 , ..., 123.45755 , 124.18375 ,
#            122.50461 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.930000066757202,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfe',
#    '_id': '500437591315015045_ZTF18aarwvfe',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.820140838623047,
#    'obs_days': 2458254.9375926,
#    'seeing': 2.930000066757202,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[125.39441 , 119.12848 , 119.85814 , ..., 116.66223 , 123.87539 ,
#                   nan],
#           [120.07695 , 122.403275, 123.58795 , ..., 127.35673 , 121.425644,
#                   nan],
#           [117.477905, 124.124466, 126.592224, ..., 128.18027 , 115.513504,
#                   nan],
#           ...,
#           [126.00398 , 130.90143 , 130.54263 , ..., 122.50885 , 121.133606,
#            118.98976 ],
#           [130.01434 , 118.703445, 122.392136, ..., 129.69894 , 121.73154 ,
#            128.19768 ],
#           [119.43631 , 116.60925 , 121.48587 , ..., 123.45755 , 124.18375 ,
#            122.50461 ]], dtype=float32),
#    'sky_pixel_values': array([125.39441, 119.12848, 119.85814, ..., 123.45755, 124.18375,
#           122.50461], dtype=float32),
#    'filtered_sky_pixel_values': array([125.39441, 119.12848, 119.85814, ..., 123.45755, 124.18375,
#           122.50461], dtype=float32),
#    'sky_value': 121.91888},
#   {'science_stamp': array([[126.39078 , 125.59916 , 127.3325  , ..., 129.00722 , 115.64969 ,
#            120.6658  ],
#           [118.3598  , 123.23596 , 117.94486 , ..., 122.869354, 122.24829 ,
#            128.6747  ],
#           [122.42768 , 118.83515 , 122.626686, ..., 123.35588 , 113.833206,
#            129.85669 ],
#           ...,
#           [139.60022 , 128.6317  , 129.38571 , ..., 119.84256 , 128.2263  ,
#            124.725075],
#           [123.31756 , 129.78174 , 120.86427 , ..., 121.14822 , 122.8622  ,
#            120.144844],
#           [117.55347 , 120.25249 , 123.847336, ..., 114.84981 , 125.74552 ,
#            121.74549 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.240000009536743,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfe',
#    '_id': '501420851315015046_ZTF18aarwvfe',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.689786911010742,
#    'obs_days': 2458255.9208565,
#    'seeing': 2.240000009536743,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[126.39078 , 125.59916 , 127.3325  , ..., 129.00722 , 115.64969 ,
#            120.6658  ],
#           [118.3598  , 123.23596 , 117.94486 , ..., 122.869354, 122.24829 ,
#            128.6747  ],
#           [122.42768 , 118.83515 , 122.626686, ..., 123.35588 , 113.833206,
#            129.85669 ],
#           ...,
#           [139.60022 , 128.6317  , 129.38571 , ..., 119.84256 , 128.2263  ,
#            124.725075],
#           [123.31756 , 129.78174 , 120.86427 , ..., 121.14822 , 122.8622  ,
#            120.144844],
#           [117.55347 , 120.25249 , 123.847336, ..., 114.84981 , 125.74552 ,
#            121.74549 ]], dtype=float32),
#    'sky_pixel_values': array([126.39078, 125.59916, 127.3325 , ..., 114.84981, 125.74552,
#           121.74549], dtype=float32),
#    'filtered_sky_pixel_values': array([126.39078, 125.59916, 127.3325 , ..., 114.84981, 125.74552,
#           121.74549], dtype=float32),
#    'sky_value': 122.22545}],
#  'Field02': [{'science_stamp': array([[122.37862 , 125.15303 , 123.839096, ..., 117.393295, 119.196106,
#            117.52697 ],
#           [       nan,        nan,        nan, ..., 122.42023 , 125.11634 ,
#            125.55972 ],
#           [       nan,        nan,        nan, ..., 125.36287 , 119.98078 ,
#            128.12271 ],
#           ...,
#           [119.99878 , 115.08452 , 124.890884, ..., 123.31642 , 125.29732 ,
#            129.34439 ],
#           [127.111725, 120.04401 , 130.01984 , ..., 114.96689 , 120.10591 ,
#            125.23929 ],
#           [116.34625 , 127.42993 , 125.155624, ..., 112.90503 , 126.726074,
#            128.63806 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.409999966621399,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfw',
#    '_id': '493392771315015055_ZTF18aarwvfw',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.87923812866211,
#    'obs_days': 2458247.8927778,
#    'seeing': 1.409999966621399,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[122.37862 , 125.15303 , 123.839096, ..., 117.393295, 119.196106,
#            117.52697 ],
#           [       nan,        nan,        nan, ..., 122.42023 , 125.11634 ,
#            125.55972 ],
#           [       nan,        nan,        nan, ..., 125.36287 , 119.98078 ,
#            128.12271 ],
#           ...,
#           [119.99878 , 115.08452 , 124.890884, ..., 123.31642 , 125.29732 ,
#            129.34439 ],
#           [127.111725, 120.04401 , 130.01984 , ..., 114.96689 , 120.10591 ,
#            125.23929 ],
#           [116.34625 , 127.42993 , 125.155624, ..., 112.90503 , 126.726074,
#            128.63806 ]], dtype=float32),
#    'sky_pixel_values': array([122.37862 , 125.15303 , 123.839096, ..., 112.90503 , 126.726074,
#           128.63806 ], dtype=float32),
#    'filtered_sky_pixel_values': array([122.37862 , 125.15303 , 123.839096, ..., 112.90503 , 126.726074,
#           128.63806 ], dtype=float32),
#    'sky_value': 121.46695},
#   {'science_stamp': array([[121.63355 , 120.56632 , 123.80816 , ..., 116.55597 , 117.54114 ,
#            120.427505],
#           [127.863625, 126.509   , 119.54654 , ..., 116.66687 , 123.785614,
#            116.69418 ],
#           [141.06015 , 153.26219 , 129.04669 , ..., 125.12755 , 124.50464 ,
#            116.92316 ],
#           ...,
#           [112.24861 , 118.007965, 126.0515  , ..., 122.634735, 118.51427 ,
#            120.1183  ],
#           [120.24873 , 112.43956 , 125.285065, ..., 121.27371 , 121.51564 ,
#            130.07704 ],
#           [114.14896 , 116.12529 , 117.793396, ..., 120.512054, 129.14357 ,
#            124.18074 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.2814245223999023,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfw',
#    '_id': '498440401315015049_ZTF18aarwvfw',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.955190658569336,
#    'obs_days': 2458252.9404051,
#    'seeing': 1.2814245223999023,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[121.63355 , 120.56632 , 123.80816 , ..., 116.55597 , 117.54114 ,
#            120.427505],
#           [127.863625, 126.509   , 119.54654 , ..., 116.66687 , 123.785614,
#            116.69418 ],
#           [141.06015 , 153.26219 , 129.04669 , ..., 125.12755 , 124.50464 ,
#            116.92316 ],
#           ...,
#           [112.24861 , 118.007965, 126.0515  , ..., 122.634735, 118.51427 ,
#            120.1183  ],
#           [120.24873 , 112.43956 , 125.285065, ..., 121.27371 , 121.51564 ,
#            130.07704 ],
#           [114.14896 , 116.12529 , 117.793396, ..., 120.512054, 129.14357 ,
#            124.18074 ]], dtype=float32),
#    'sky_pixel_values': array([121.63355 , 120.56632 , 123.80816 , ..., 120.512054, 129.14357 ,
#           124.18074 ], dtype=float32),
#    'filtered_sky_pixel_values': array([121.63355 , 120.56632 , 123.80816 , ..., 120.512054, 129.14357 ,
#           124.18074 ], dtype=float32),
#    'sky_value': 121.32055},
#   {'science_stamp': array([[129.29004 , 124.736984, 121.99963 , ..., 119.25351 , 118.14748 ,
#            122.98359 ],
#           [128.2492  , 136.25165 , 122.81734 , ..., 131.3715  , 116.341385,
#            128.20007 ],
#           [129.60861 , 154.92429 , 141.21567 , ..., 119.94581 , 115.08767 ,
#            120.40937 ],
#           ...,
#           [116.91059 , 115.814995, 118.55896 , ..., 117.59196 , 125.74109 ,
#            118.66974 ],
#           [113.88347 , 117.301315, 123.498856, ..., 112.411514, 117.440765,
#            128.25305 ],
#           [113.47845 , 126.10119 , 130.76678 , ..., 118.177956, 117.31424 ,
#            121.956184]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.609999895095825,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfw',
#    '_id': '500437591315015036_ZTF18aarwvfw',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.820140838623047,
#    'obs_days': 2458254.9375926,
#    'seeing': 2.609999895095825,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[129.29004 , 124.736984, 121.99963 , ..., 119.25351 , 118.14748 ,
#            122.98359 ],
#           [128.2492  , 136.25165 , 122.81734 , ..., 131.3715  , 116.341385,
#            128.20007 ],
#           [129.60861 , 154.92429 , 141.21567 , ..., 119.94581 , 115.08767 ,
#            120.40937 ],
#           ...,
#           [116.91059 , 115.814995, 118.55896 , ..., 117.59196 , 125.74109 ,
#            118.66974 ],
#           [113.88347 , 117.301315, 123.498856, ..., 112.411514, 117.440765,
#            128.25305 ],
#           [113.47845 , 126.10119 , 130.76678 , ..., 118.177956, 117.31424 ,
#            121.956184]], dtype=float32),
#    'sky_pixel_values': array([129.29004 , 124.736984, 121.99963 , ..., 118.177956, 117.31424 ,
#           121.956184], dtype=float32),
#    'filtered_sky_pixel_values': array([129.29004 , 124.736984, 121.99963 , ..., 118.177956, 117.31424 ,
#           121.956184], dtype=float32),
#    'sky_value': 121.34891},
#   {'science_stamp': array([[123.2623  , 128.59918 , 116.87988 , ..., 123.59504 , 121.94188 ,
#            120.006836],
#           [133.5283  , 128.23274 , 129.89255 , ..., 118.25766 , 115.91594 ,
#            110.94215 ],
#           [136.44164 , 138.49649 , 120.05768 , ..., 125.53945 , 125.96063 ,
#            124.85569 ],
#           ...,
#           [122.6772  , 125.11847 , 118.11333 , ..., 124.81268 , 125.88869 ,
#            127.37369 ],
#           [133.25377 , 115.00319 , 119.918686, ..., 120.724304, 123.02606 ,
#            120.485016],
#           [121.11215 , 119.71352 , 125.793045, ..., 120.65079 , 119.285614,
#            126.839386]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.509999990463257,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aarwvfw',
#    '_id': '501420851315015035_ZTF18aarwvfw',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.689786911010742,
#    'obs_days': 2458255.9208565,
#    'seeing': 2.509999990463257,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[123.2623  , 128.59918 , 116.87988 , ..., 123.59504 , 121.94188 ,
#            120.006836],
#           [133.5283  , 128.23274 , 129.89255 , ..., 118.25766 , 115.91594 ,
#            110.94215 ],
#           [136.44164 , 138.49649 , 120.05768 , ..., 125.53945 , 125.96063 ,
#            124.85569 ],
#           ...,
#           [122.6772  , 125.11847 , 118.11333 , ..., 124.81268 , 125.88869 ,
#            127.37369 ],
#           [133.25377 , 115.00319 , 119.918686, ..., 120.724304, 123.02606 ,
#            120.485016],
#           [121.11215 , 119.71352 , 125.793045, ..., 120.65079 , 119.285614,
#            126.839386]], dtype=float32),
#    'sky_pixel_values': array([123.2623  , 128.59918 , 116.87988 , ..., 120.65079 , 119.285614,
#           126.839386], dtype=float32),
#    'filtered_sky_pixel_values': array([123.2623  , 128.59918 , 116.87988 , ..., 120.65079 , 119.285614,
#           126.839386], dtype=float32),
#    'sky_value': 121.17121}],
#  'Field03': [{'science_stamp': array([[160.4582 , 172.04256, 163.62102, ..., 168.16054, 170.83463,
#            173.90524],
#           [169.80515, 166.58118, 169.92126, ..., 162.33844, 164.36163,
#            160.54741],
#           [167.0014 , 176.08713, 173.31396, ..., 163.38239, 161.73227,
#            166.15375],
#           ...,
#           [163.9837 , 168.44427, 169.05939, ..., 166.63545, 165.84824,
#            162.74222],
#           [163.18018, 171.75348, 168.96756, ..., 157.12215, 172.71933,
#            155.71754],
#           [166.43744, 167.09634, 161.50098, ..., 163.7875 , 172.52686,
#            171.41772]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.3178703784942627,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwvob',
#    '_id': '493392771615015022_ZTF18aarwvob',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.747987747192383,
#    'obs_days': 2458247.8927778,
#    'seeing': 1.3178703784942627,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[160.4582 , 172.04256, 163.62102, ..., 168.16054, 170.83463,
#            173.90524],
#           [169.80515, 166.58118, 169.92126, ..., 162.33844, 164.36163,
#            160.54741],
#           [167.0014 , 176.08713, 173.31396, ..., 163.38239, 161.73227,
#            166.15375],
#           ...,
#           [163.9837 , 168.44427, 169.05939, ..., 166.63545, 165.84824,
#            162.74222],
#           [163.18018, 171.75348, 168.96756, ..., 157.12215, 172.71933,
#            155.71754],
#           [166.43744, 167.09634, 161.50098, ..., 163.7875 , 172.52686,
#            171.41772]], dtype=float32),
#    'sky_pixel_values': array([160.4582 , 172.04256, 163.62102, ..., 163.7875 , 172.52686,
#           171.41772], dtype=float32),
#    'filtered_sky_pixel_values': array([160.4582 , 172.04256, 163.62102, ..., 163.7875 , 172.52686,
#           171.41772], dtype=float32),
#    'sky_value': 167.93529},
#   {'science_stamp': array([[163.00522, 166.0028 , 167.64926, ..., 166.89777, 163.4364 ,
#            170.91547],
#           [166.54819, 163.6818 , 170.06685, ..., 173.55533, 166.40771,
#            169.25342],
#           [168.09921, 165.2892 , 166.7581 , ..., 165.45721, 179.72668,
#            167.04074],
#           ...,
#           [168.47717, 163.19551, 169.27824, ..., 164.20963, 162.41971,
#            163.6505 ],
#           [170.72546, 172.92072, 171.202  , ..., 161.50711, 177.9975 ,
#            170.2922 ],
#           [163.54932, 171.87097, 167.84035, ..., 164.84415, 162.29518,
#            159.12907]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.2899999618530273,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwvob',
#    '_id': '498440401615015026_ZTF18aarwvob',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.829524993896484,
#    'obs_days': 2458252.9404051,
#    'seeing': 3.2899999618530273,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[163.00522, 166.0028 , 167.64926, ..., 166.89777, 163.4364 ,
#            170.91547],
#           [166.54819, 163.6818 , 170.06685, ..., 173.55533, 166.40771,
#            169.25342],
#           [168.09921, 165.2892 , 166.7581 , ..., 165.45721, 179.72668,
#            167.04074],
#           ...,
#           [168.47717, 163.19551, 169.27824, ..., 164.20963, 162.41971,
#            163.6505 ],
#           [170.72546, 172.92072, 171.202  , ..., 161.50711, 177.9975 ,
#            170.2922 ],
#           [163.54932, 171.87097, 167.84035, ..., 164.84415, 162.29518,
#            159.12907]], dtype=float32),
#    'sky_pixel_values': array([163.00522, 166.0028 , 167.64926, ..., 164.84415, 162.29518,
#           159.12907], dtype=float32),
#    'filtered_sky_pixel_values': array([163.00522, 166.0028 , 167.64926, ..., 164.84415, 162.29518,
#           159.12907], dtype=float32),
#    'sky_value': 167.60895},
#   {'science_stamp': array([[160.79504, 161.15677, 174.92749, ..., 172.16122, 173.7218 ,
#            165.85172],
#           [174.11673, 166.08124, 173.61536, ..., 176.14575, 168.89484,
#            166.84894],
#           [171.45747, 166.90335, 164.36812, ..., 168.98808, 166.96454,
#            168.09973],
#           ...,
#           [172.63333, 168.35298, 167.27603, ..., 173.3154 , 167.65195,
#            172.32866],
#           [159.41284, 165.9655 , 162.48776, ..., 161.97018, 178.23679,
#            168.09018],
#           [174.54926, 173.04723, 172.60364, ..., 166.72491, 169.73299,
#            167.83716]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.2300000190734863,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwvob',
#    '_id': '500437591615010010_ZTF18aarwvob',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.891094207763672,
#    'obs_days': 2458254.9375926,
#    'seeing': 3.2300000190734863,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[160.79504, 161.15677, 174.92749, ..., 172.16122, 173.7218 ,
#            165.85172],
#           [174.11673, 166.08124, 173.61536, ..., 176.14575, 168.89484,
#            166.84894],
#           [171.45747, 166.90335, 164.36812, ..., 168.98808, 166.96454,
#            168.09973],
#           ...,
#           [172.63333, 168.35298, 167.27603, ..., 173.3154 , 167.65195,
#            172.32866],
#           [159.41284, 165.9655 , 162.48776, ..., 161.97018, 178.23679,
#            168.09018],
#           [174.54926, 173.04723, 172.60364, ..., 166.72491, 169.73299,
#            167.83716]], dtype=float32),
#    'sky_pixel_values': array([160.79504, 161.15677, 174.92749, ..., 166.72491, 169.73299,
#           167.83716], dtype=float32),
#    'filtered_sky_pixel_values': array([160.79504, 161.15677, 174.92749, ..., 166.72491, 169.73299,
#           167.83716], dtype=float32),
#    'sky_value': 167.75655}],
#  'Field04': [{'science_stamp': array([[131.64026 , 123.01469 , 123.67559 , ..., 118.7479  , 121.528366,
#            120.59587 ],
#           [127.75495 , 118.18553 , 129.34555 , ..., 127.96509 , 115.23842 ,
#            124.408195],
#           [131.75737 , 116.87368 , 125.08768 , ..., 121.229256, 122.67532 ,
#            123.604774],
#           ...,
#           [130.71542 , 120.87318 , 126.73164 , ..., 119.93501 , 128.46744 ,
#            123.10465 ],
#           [124.010826, 127.23073 , 127.00197 , ..., 123.64285 , 131.33643 ,
#            128.23122 ],
#           [128.39069 , 116.05744 , 132.12398 , ..., 129.85504 , 124.35833 ,
#            122.22436 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.5,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwweh',
#    '_id': '493392771215015023_ZTF18aarwweh',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.961483001708984,
#    'obs_days': 2458247.8927778,
#    'seeing': 2.5,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[131.64026 , 123.01469 , 123.67559 , ..., 118.7479  , 121.528366,
#            120.59587 ],
#           [127.75495 , 118.18553 , 129.34555 , ..., 127.96509 , 115.23842 ,
#            124.408195],
#           [131.75737 , 116.87368 , 125.08768 , ..., 121.229256, 122.67532 ,
#            123.604774],
#           ...,
#           [130.71542 , 120.87318 , 126.73164 , ..., 119.93501 , 128.46744 ,
#            123.10465 ],
#           [124.010826, 127.23073 , 127.00197 , ..., 123.64285 , 131.33643 ,
#            128.23122 ],
#           [128.39069 , 116.05744 , 132.12398 , ..., 129.85504 , 124.35833 ,
#            122.22436 ]], dtype=float32),
#    'sky_pixel_values': array([131.64026, 123.01469, 123.67559, ..., 129.85504, 124.35833,
#           122.22436], dtype=float32),
#    'filtered_sky_pixel_values': array([131.64026, 123.01469, 123.67559, ..., 129.85504, 124.35833,
#           122.22436], dtype=float32),
#    'sky_value': 123.563644},
#   {'science_stamp': array([[115.714645, 123.37558 , 120.03206 , ..., 127.186554, 121.0974  ,
#            132.51294 ],
#           [122.73984 , 131.21167 , 122.917435, ..., 120.26335 , 128.35942 ,
#            116.069786],
#           [120.67819 , 131.50171 , 127.353134, ..., 119.79355 , 121.63898 ,
#            118.46336 ],
#           ...,
#           [125.7084  , 120.38705 , 120.04703 , ..., 121.94487 , 116.53865 ,
#            120.584305],
#           [128.96298 , 129.47583 , 113.88247 , ..., 116.84497 , 122.8168  ,
#            121.659195],
#           [125.3647  , 121.1842  , 127.20799 , ..., 122.45563 , 118.17613 ,
#            123.05745 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.190000057220459,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwweh',
#    '_id': '498440401215015017_ZTF18aarwweh',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 21.02008819580078,
#    'obs_days': 2458252.9404051,
#    'seeing': 3.190000057220459,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[115.714645, 123.37558 , 120.03206 , ..., 127.186554, 121.0974  ,
#            132.51294 ],
#           [122.73984 , 131.21167 , 122.917435, ..., 120.26335 , 128.35942 ,
#            116.069786],
#           [120.67819 , 131.50171 , 127.353134, ..., 119.79355 , 121.63898 ,
#            118.46336 ],
#           ...,
#           [125.7084  , 120.38705 , 120.04703 , ..., 121.94487 , 116.53865 ,
#            120.584305],
#           [128.96298 , 129.47583 , 113.88247 , ..., 116.84497 , 122.8168  ,
#            121.659195],
#           [125.3647  , 121.1842  , 127.20799 , ..., 122.45563 , 118.17613 ,
#            123.05745 ]], dtype=float32),
#    'sky_pixel_values': array([115.714645, 123.37558 , 120.03206 , ..., 122.45563 , 118.17613 ,
#           123.05745 ], dtype=float32),
#    'filtered_sky_pixel_values': array([115.714645, 123.37558 , 120.03206 , ..., 122.45563 , 118.17613 ,
#           123.05745 ], dtype=float32),
#    'sky_value': 123.33735},
#   {'science_stamp': array([[128.04964 , 119.15889 , 118.7345  , ..., 119.94652 , 120.34804 ,
#            122.50818 ],
#           [120.74242 , 126.01306 , 131.1883  , ..., 123.922226, 123.23899 ,
#            131.81042 ],
#           [119.64694 , 127.45813 , 134.4986  , ..., 123.38969 , 113.7699  ,
#            128.69899 ],
#           ...,
#           [140.54416 , 116.27248 , 120.69459 , ..., 125.371315, 123.87418 ,
#            124.9906  ],
#           [132.76436 , 123.22791 , 125.848495, ..., 120.71534 , 120.67598 ,
#            122.10093 ],
#           [124.60893 , 123.8847  , 119.30386 , ..., 118.738365, 125.21286 ,
#            123.20562 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.109999895095825,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwweh',
#    '_id': '500437591215015016_ZTF18aarwweh',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.90336036682129,
#    'obs_days': 2458254.9375926,
#    'seeing': 3.109999895095825,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[128.04964 , 119.15889 , 118.7345  , ..., 119.94652 , 120.34804 ,
#            122.50818 ],
#           [120.74242 , 126.01306 , 131.1883  , ..., 123.922226, 123.23899 ,
#            131.81042 ],
#           [119.64694 , 127.45813 , 134.4986  , ..., 123.38969 , 113.7699  ,
#            128.69899 ],
#           ...,
#           [140.54416 , 116.27248 , 120.69459 , ..., 125.371315, 123.87418 ,
#            124.9906  ],
#           [132.76436 , 123.22791 , 125.848495, ..., 120.71534 , 120.67598 ,
#            122.10093 ],
#           [124.60893 , 123.8847  , 119.30386 , ..., 118.738365, 125.21286 ,
#            123.20562 ]], dtype=float32),
#    'sky_pixel_values': array([128.04964 , 119.15889 , 118.7345  , ..., 118.738365, 125.21286 ,
#           123.20562 ], dtype=float32),
#    'filtered_sky_pixel_values': array([128.04964 , 119.15889 , 118.7345  , ..., 118.738365, 125.21286 ,
#           123.20562 ], dtype=float32),
#    'sky_value': 123.416016},
#   {'science_stamp': array([[131.15562 , 121.637665, 124.36359 , ..., 120.14485 , 114.193924,
#            127.43974 ],
#           [128.13509 , 125.38771 , 119.00325 , ..., 124.33464 , 116.66162 ,
#            122.72093 ],
#           [126.04387 , 127.8002  , 125.85361 , ..., 117.87193 , 118.44026 ,
#            117.15752 ],
#           ...,
#           [136.38292 , 119.42522 , 118.81972 , ..., 121.08832 , 128.79364 ,
#            120.813934],
#           [129.73767 , 126.75363 , 126.08363 , ..., 115.42856 , 125.83438 ,
#            123.57451 ],
#           [125.13846 , 125.57555 , 122.10977 , ..., 122.27327 , 119.80444 ,
#            120.53264 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.1500000953674316,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aarwweh',
#    '_id': '501420851215015015_ZTF18aarwweh',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.783693313598633,
#    'obs_days': 2458255.9208565,
#    'seeing': 3.1500000953674316,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[131.15562 , 121.637665, 124.36359 , ..., 120.14485 , 114.193924,
#            127.43974 ],
#           [128.13509 , 125.38771 , 119.00325 , ..., 124.33464 , 116.66162 ,
#            122.72093 ],
#           [126.04387 , 127.8002  , 125.85361 , ..., 117.87193 , 118.44026 ,
#            117.15752 ],
#           ...,
#           [136.38292 , 119.42522 , 118.81972 , ..., 121.08832 , 128.79364 ,
#            120.813934],
#           [129.73767 , 126.75363 , 126.08363 , ..., 115.42856 , 125.83438 ,
#            123.57451 ],
#           [125.13846 , 125.57555 , 122.10977 , ..., 122.27327 , 119.80444 ,
#            120.53264 ]], dtype=float32),
#    'sky_pixel_values': array([131.15562 , 121.637665, 124.36359 , ..., 122.27327 , 119.80444 ,
#           120.53264 ], dtype=float32),
#    'filtered_sky_pixel_values': array([131.15562 , 121.637665, 124.36359 , ..., 122.27327 , 119.80444 ,
#           120.53264 ], dtype=float32),
#    'sky_value': 123.37239}],
#  'Field05': [{'science_stamp': array([[      nan,       nan,       nan, ..., 132.07445, 129.41779,
#            124.51422],
#           [      nan,       nan,       nan, ..., 136.54657, 131.42346,
#            128.39622],
#           [      nan,       nan,       nan, ..., 179.6283 , 128.01353,
#            127.1552 ],
#           ...,
#           [      nan,       nan,       nan, ..., 139.73999, 130.83966,
#            129.34549],
#           [      nan,       nan,       nan, ..., 171.75569, 132.14299,
#            133.97482],
#           [      nan,       nan,       nan, ..., 230.01953, 160.54294,
#            149.92528]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.2826560735702515,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '493392771215015008_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.961483001708984,
#    'obs_days': 2458247.8927778,
#    'seeing': 1.2826560735702515,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[      nan,       nan,       nan, ..., 132.07445, 129.41779,
#            124.51422],
#           [      nan,       nan,       nan, ..., 136.54657, 131.42346,
#            128.39622],
#           [      nan,       nan,       nan, ..., 179.6283 , 128.01353,
#            127.1552 ],
#           ...,
#           [      nan,       nan,       nan, ..., 139.73999, 130.83966,
#            129.34549],
#           [      nan,       nan,       nan, ..., 171.75569, 132.14299,
#            133.97482],
#           [      nan,       nan,       nan, ..., 230.01953, 160.54294,
#            149.92528]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 230.01953, 160.54294,
#           149.92528], dtype=float32),
#    'filtered_sky_pixel_values': array([124.16615, 121.31975, 126.11311, ..., 132.898  , 132.46642,
#           131.79341], dtype=float32),
#    'sky_value': 126.887215},
#   {'science_stamp': array([[       nan,        nan,        nan, ..., 125.96102 , 123.07139 ,
#            131.0886  ],
#           [       nan,        nan,        nan, ..., 152.94019 , 127.535545,
#            129.36029 ],
#           [       nan,        nan,        nan, ..., 280.32767 , 146.15652 ,
#            120.671906],
#           ...,
#           [       nan,        nan,        nan, ..., 160.03801 , 143.88501 ,
#            133.50903 ],
#           [       nan,        nan,        nan, ..., 206.29056 , 151.03777 ,
#            127.5363  ],
#           [       nan,        nan,        nan, ..., 359.184   , 180.72777 ,
#            162.5139  ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 4.679999828338623,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '498440401215015005_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 21.02008819580078,
#    'obs_days': 2458252.9404051,
#    'seeing': 4.679999828338623,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[       nan,        nan,        nan, ..., 125.96102 , 123.07139 ,
#            131.0886  ],
#           [       nan,        nan,        nan, ..., 152.94019 , 127.535545,
#            129.36029 ],
#           [       nan,        nan,        nan, ..., 280.32767 , 146.15652 ,
#            120.671906],
#           ...,
#           [       nan,        nan,        nan, ..., 160.03801 , 143.88501 ,
#            133.50903 ],
#           [       nan,        nan,        nan, ..., 206.29056 , 151.03777 ,
#            127.5363  ],
#           [       nan,        nan,        nan, ..., 359.184   , 180.72777 ,
#            162.5139  ]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 359.184  , 180.72777,
#           162.5139 ], dtype=float32),
#    'filtered_sky_pixel_values': array([125.04199, 124.24792, 120.32707, ..., 132.66718, 126.96306,
#           127.41142], dtype=float32),
#    'sky_value': 126.55852},
#   {'science_stamp': array([[       nan,        nan,        nan, ..., 125.96102 , 123.07139 ,
#            131.0886  ],
#           [       nan,        nan,        nan, ..., 152.94019 , 127.535545,
#            129.36029 ],
#           [       nan,        nan,        nan, ..., 280.32767 , 146.15652 ,
#            120.671906],
#           ...,
#           [       nan,        nan,        nan, ..., 160.03801 , 143.88501 ,
#            133.50903 ],
#           [       nan,        nan,        nan, ..., 206.29056 , 151.03777 ,
#            127.5363  ],
#           [       nan,        nan,        nan, ..., 359.184   , 180.72777 ,
#            162.5139  ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.299999952316284,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '498440401215015006_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 21.02008819580078,
#    'obs_days': 2458252.9404051,
#    'seeing': 2.299999952316284,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[       nan,        nan,        nan, ..., 125.96102 , 123.07139 ,
#            131.0886  ],
#           [       nan,        nan,        nan, ..., 152.94019 , 127.535545,
#            129.36029 ],
#           [       nan,        nan,        nan, ..., 280.32767 , 146.15652 ,
#            120.671906],
#           ...,
#           [       nan,        nan,        nan, ..., 160.03801 , 143.88501 ,
#            133.50903 ],
#           [       nan,        nan,        nan, ..., 206.29056 , 151.03777 ,
#            127.5363  ],
#           [       nan,        nan,        nan, ..., 359.184   , 180.72777 ,
#            162.5139  ]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 359.184  , 180.72777,
#           162.5139 ], dtype=float32),
#    'filtered_sky_pixel_values': array([125.04199, 124.24792, 120.32707, ..., 132.66718, 126.96306,
#           127.41142], dtype=float32),
#    'sky_value': 126.68519},
#   {'science_stamp': array([[       nan,        nan,        nan, ..., 124.96112 , 123.74222 ,
#            119.02142 ],
#           [       nan,        nan,        nan, ..., 151.65538 , 122.38469 ,
#            122.289764],
#           [       nan,        nan,        nan, ..., 211.34557 , 147.64989 ,
#            129.76088 ],
#           ...,
#           [       nan,        nan,        nan, ..., 156.88162 , 135.03937 ,
#            119.5508  ],
#           [       nan,        nan,        nan, ..., 189.96727 , 145.17543 ,
#            132.47102 ],
#           [       nan,        nan,        nan, ..., 270.6607  , 186.0903  ,
#            165.10805 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.325039267539978,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '500437591215015007_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.90336036682129,
#    'obs_days': 2458254.9375926,
#    'seeing': 1.325039267539978,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[       nan,        nan,        nan, ..., 124.96112 , 123.74222 ,
#            119.02142 ],
#           [       nan,        nan,        nan, ..., 151.65538 , 122.38469 ,
#            122.289764],
#           [       nan,        nan,        nan, ..., 211.34557 , 147.64989 ,
#            129.76088 ],
#           ...,
#           [       nan,        nan,        nan, ..., 156.88162 , 135.03937 ,
#            119.5508  ],
#           [       nan,        nan,        nan, ..., 189.96727 , 145.17543 ,
#            132.47102 ],
#           [       nan,        nan,        nan, ..., 270.6607  , 186.0903  ,
#            165.10805 ]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 270.6607 , 186.0903 ,
#           165.10805], dtype=float32),
#    'filtered_sky_pixel_values': array([123.60866 , 123.68309 , 125.728455, ..., 130.21524 , 131.7248  ,
#           132.9738  ], dtype=float32),
#    'sky_value': 127.462364},
#   {'science_stamp': array([[       nan,        nan,        nan, ..., 120.48697 , 126.39964 ,
#            126.84285 ],
#           [       nan,        nan,        nan, ..., 124.96112 , 123.74222 ,
#            119.02142 ],
#           [       nan,        nan,        nan, ..., 151.65538 , 122.38469 ,
#            122.289764],
#           ...,
#           [       nan,        nan,        nan, ..., 142.54126 , 132.8789  ,
#            134.06348 ],
#           [       nan,        nan,        nan, ..., 156.88162 , 135.03937 ,
#            119.5508  ],
#           [       nan,        nan,        nan, ..., 189.96727 , 145.17543 ,
#            132.47102 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.325039267539978,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '500437591215015008_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.90336036682129,
#    'obs_days': 2458254.9375926,
#    'seeing': 1.325039267539978,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[       nan,        nan,        nan, ..., 120.48697 , 126.39964 ,
#            126.84285 ],
#           [       nan,        nan,        nan, ..., 124.96112 , 123.74222 ,
#            119.02142 ],
#           [       nan,        nan,        nan, ..., 151.65538 , 122.38469 ,
#            122.289764],
#           ...,
#           [       nan,        nan,        nan, ..., 142.54126 , 132.8789  ,
#            134.06348 ],
#           [       nan,        nan,        nan, ..., 156.88162 , 135.03937 ,
#            119.5508  ],
#           [       nan,        nan,        nan, ..., 189.96727 , 145.17543 ,
#            132.47102 ]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 189.96727, 145.17543,
#           132.47102], dtype=float32),
#    'filtered_sky_pixel_values': array([127.28903, 129.61485, 124.94969, ..., 134.35971, 135.88445,
#           132.47102], dtype=float32),
#    'sky_value': 127.46454},
#   {'science_stamp': array([[       nan,        nan,        nan, ..., 120.39592 , 129.46066 ,
#            124.87707 ],
#           [       nan,        nan,        nan, ..., 138.00977 , 129.83441 ,
#            128.09335 ],
#           [       nan,        nan,        nan, ..., 184.52603 , 139.25464 ,
#            135.48737 ],
#           ...,
#           [       nan,        nan,        nan, ..., 158.57181 , 137.19868 ,
#            127.908295],
#           [       nan,        nan,        nan, ..., 194.37738 , 150.08392 ,
#            139.05109 ],
#           [       nan,        nan,        nan, ..., 254.50554 , 181.7475  ,
#            156.9867  ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.3545012474060059,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aarwwex',
#    '_id': '501420851215015005_ZTF18aarwwex',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.783693313598633,
#    'obs_days': 2458255.9208565,
#    'seeing': 1.3545012474060059,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[       nan,        nan,        nan, ..., 120.39592 , 129.46066 ,
#            124.87707 ],
#           [       nan,        nan,        nan, ..., 138.00977 , 129.83441 ,
#            128.09335 ],
#           [       nan,        nan,        nan, ..., 184.52603 , 139.25464 ,
#            135.48737 ],
#           ...,
#           [       nan,        nan,        nan, ..., 158.57181 , 137.19868 ,
#            127.908295],
#           [       nan,        nan,        nan, ..., 194.37738 , 150.08392 ,
#            139.05109 ],
#           [       nan,        nan,        nan, ..., 254.50554 , 181.7475  ,
#            156.9867  ]], dtype=float32),
#    'sky_pixel_values': array([      nan,       nan,       nan, ..., 254.50554, 181.7475 ,
#           156.9867 ], dtype=float32),
#    'filtered_sky_pixel_values': array([123.76353 , 123.28318 , 124.834724, ..., 134.7682  , 132.06042 ,
#           136.50485 ], dtype=float32),
#    'sky_value': 127.76081}],
#  'Field06': [{'science_stamp': array([[128.94958 , 120.751465, 123.29907 , ..., 126.44614 , 131.28209 ,
#            128.10464 ],
#           [124.52581 , 133.56824 , 123.95816 , ..., 125.56357 , 119.40102 ,
#            122.58237 ],
#           [119.461624, 125.51649 , 122.19454 , ..., 127.958786, 130.19669 ,
#            125.50038 ],
#           ...,
#           [120.78911 , 127.97568 , 126.7076  , ..., 129.3893  , 122.66356 ,
#            125.52675 ],
#           [123.82943 , 125.23937 , 125.86594 , ..., 117.202805, 135.13274 ,
#            123.971146],
#           [127.921265, 122.822334, 126.553795, ..., 117.5331  , 127.70923 ,
#            133.24226 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.390000104904175,
#    'mjd': 2458247.8927778,
#    'field': 639,
#    'object_id': 'ZTF18aarwwgv',
#    '_id': '493392771215015121_ZTF18aarwwgv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.961483001708984,
#    'obs_days': 2458247.8927778,
#    'seeing': 2.390000104904175,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[128.94958 , 120.751465, 123.29907 , ..., 126.44614 , 131.28209 ,
#            128.10464 ],
#           [124.52581 , 133.56824 , 123.95816 , ..., 125.56357 , 119.40102 ,
#            122.58237 ],
#           [119.461624, 125.51649 , 122.19454 , ..., 127.958786, 130.19669 ,
#            125.50038 ],
#           ...,
#           [120.78911 , 127.97568 , 126.7076  , ..., 129.3893  , 122.66356 ,
#            125.52675 ],
#           [123.82943 , 125.23937 , 125.86594 , ..., 117.202805, 135.13274 ,
#            123.971146],
#           [127.921265, 122.822334, 126.553795, ..., 117.5331  , 127.70923 ,
#            133.24226 ]], dtype=float32),
#    'sky_pixel_values': array([128.94958 , 120.751465, 123.29907 , ..., 117.5331  , 127.70923 ,
#           133.24226 ], dtype=float32),
#    'filtered_sky_pixel_values': array([128.94958 , 120.751465, 123.29907 , ..., 117.5331  , 127.70923 ,
#           133.24226 ], dtype=float32),
#    'sky_value': 126.12054},
#   {'science_stamp': array([[125.73233 , 125.853745, 118.88345 , ..., 127.33475 , 120.90358 ,
#            128.5551  ],
#           [127.54401 , 119.07927 , 128.34247 , ..., 130.10745 , 128.25377 ,
#            134.2704  ],
#           [125.65585 , 123.84061 , 120.155266, ..., 121.7485  , 126.73765 ,
#            121.87594 ],
#           ...,
#           [119.691376, 122.70024 , 124.247894, ..., 126.31298 , 121.76662 ,
#            125.17782 ],
#           [127.8033  , 124.77756 , 120.09654 , ..., 126.78863 , 121.74201 ,
#            129.58176 ],
#           [131.05083 , 126.85748 , 125.01903 , ..., 124.872604, 121.68407 ,
#            132.92828 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.190000057220459,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aarwwgv',
#    '_id': '498440401215015109_ZTF18aarwwgv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 21.02008819580078,
#    'obs_days': 2458252.9404051,
#    'seeing': 2.190000057220459,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[125.73233 , 125.853745, 118.88345 , ..., 127.33475 , 120.90358 ,
#            128.5551  ],
#           [127.54401 , 119.07927 , 128.34247 , ..., 130.10745 , 128.25377 ,
#            134.2704  ],
#           [125.65585 , 123.84061 , 120.155266, ..., 121.7485  , 126.73765 ,
#            121.87594 ],
#           ...,
#           [119.691376, 122.70024 , 124.247894, ..., 126.31298 , 121.76662 ,
#            125.17782 ],
#           [127.8033  , 124.77756 , 120.09654 , ..., 126.78863 , 121.74201 ,
#            129.58176 ],
#           [131.05083 , 126.85748 , 125.01903 , ..., 124.872604, 121.68407 ,
#            132.92828 ]], dtype=float32),
#    'sky_pixel_values': array([125.73233 , 125.853745, 118.88345 , ..., 124.872604, 121.68407 ,
#           132.92828 ], dtype=float32),
#    'filtered_sky_pixel_values': array([125.73233 , 125.853745, 118.88345 , ..., 124.872604, 121.68407 ,
#           132.92828 ], dtype=float32),
#    'sky_value': 125.98094},
#   {'science_stamp': array([[126.14801 , 122.12659 , 130.31677 , ..., 135.2484  , 129.71407 ,
#            121.4324  ],
#           [124.55415 , 129.84598 , 127.52351 , ..., 122.44945 , 120.03607 ,
#            124.76752 ],
#           [117.42657 , 124.60579 , 132.46002 , ..., 120.50525 , 118.40614 ,
#            122.09219 ],
#           ...,
#           [123.7496  , 127.49812 , 123.04372 , ..., 124.18948 , 117.65851 ,
#            132.35123 ],
#           [126.043045, 122.72604 , 121.494644, ..., 120.32117 , 119.51671 ,
#            131.70253 ],
#           [125.16153 , 134.93396 , 128.90102 , ..., 126.7655  , 124.94864 ,
#            133.06493 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.569999933242798,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aarwwgv',
#    '_id': '500437591215015090_ZTF18aarwwgv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.90336036682129,
#    'obs_days': 2458254.9375926,
#    'seeing': 2.569999933242798,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[126.14801 , 122.12659 , 130.31677 , ..., 135.2484  , 129.71407 ,
#            121.4324  ],
#           [124.55415 , 129.84598 , 127.52351 , ..., 122.44945 , 120.03607 ,
#            124.76752 ],
#           [117.42657 , 124.60579 , 132.46002 , ..., 120.50525 , 118.40614 ,
#            122.09219 ],
#           ...,
#           [123.7496  , 127.49812 , 123.04372 , ..., 124.18948 , 117.65851 ,
#            132.35123 ],
#           [126.043045, 122.72604 , 121.494644, ..., 120.32117 , 119.51671 ,
#            131.70253 ],
#           [125.16153 , 134.93396 , 128.90102 , ..., 126.7655  , 124.94864 ,
#            133.06493 ]], dtype=float32),
#    'sky_pixel_values': array([126.14801, 122.12659, 130.31677, ..., 126.7655 , 124.94864,
#           133.06493], dtype=float32),
#    'filtered_sky_pixel_values': array([126.14801, 122.12659, 130.31677, ..., 126.7655 , 124.94864,
#           133.06493], dtype=float32),
#    'sky_value': 125.911964},
#   {'science_stamp': array([[128.26933 , 118.58426 , 134.39857 , ...,        nan, 122.266815,
#            130.39291 ],
#           [132.61836 , 123.72569 , 116.05153 , ...,        nan, 129.1215  ,
#            126.83737 ],
#           [125.41803 , 127.54001 , 123.94307 , ...,        nan, 121.80655 ,
#            124.63222 ],
#           ...,
#           [126.229996, 124.454254, 124.853714, ..., 131.70715 , 123.79077 ,
#            119.81755 ],
#           [126.864365, 136.39696 , 131.6214  , ..., 123.38977 , 131.1331  ,
#            125.235504],
#           [124.416046, 115.54941 , 125.33418 , ..., 125.553894, 122.865585,
#            124.6884  ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.2799999713897705,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aarwwgv',
#    '_id': '501420851215015069_ZTF18aarwwgv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.783693313598633,
#    'obs_days': 2458255.9208565,
#    'seeing': 2.2799999713897705,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[128.26933 , 118.58426 , 134.39857 , ...,        nan, 122.266815,
#            130.39291 ],
#           [132.61836 , 123.72569 , 116.05153 , ...,        nan, 129.1215  ,
#            126.83737 ],
#           [125.41803 , 127.54001 , 123.94307 , ...,        nan, 121.80655 ,
#            124.63222 ],
#           ...,
#           [126.229996, 124.454254, 124.853714, ..., 131.70715 , 123.79077 ,
#            119.81755 ],
# ...
#    'obs_days': 2458252.9404051,
#    'seeing': 2.3499999046325684,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[185.4114 , 185.55243, 201.9592 , ..., 176.68433, 175.6437 ,
#            179.00385],
#           [186.32008, 189.59467, 192.8068 , ..., 184.41391, 170.58028,
#            171.50824],
#           [179.90236, 183.07135, 168.27222, ..., 178.02588, 182.79109,
#            184.3051 ],
#           ...,
#           [175.04688, 175.25746, 175.284  , ..., 188.72716, 195.12756,
#            213.96378],
#           [183.96024, 176.07246, 170.51672, ..., 189.41907, 187.49352,
#            211.119  ],
#           [174.71127, 166.86382, 170.84256, ..., 180.26923, 182.4064 ,
#            183.37965]], dtype=float32),
#    'sky_pixel_values': array([185.4114 , 185.55243, 201.9592 , ..., 180.26923, 182.4064 ,
#           183.37965], dtype=float32),
#    'filtered_sky_pixel_values': array([180.8667 , 178.53873, 170.8352 , ..., 180.26923, 182.4064 ,
#           183.37965], dtype=float32),
#    'sky_value': 175.78061},
#   {'science_stamp': array([[176.80667, 189.51863, 202.04431, ..., 180.76782, 168.53426,
#            178.4661 ],
#           [180.94232, 180.92712, 192.1698 , ..., 178.02316, 171.7853 ,
#            177.65048],
#           [180.17722, 176.62057, 179.89502, ..., 183.10239, 173.32103,
#            173.24365],
#           ...,
#           [170.63162, 169.36319, 166.74664, ..., 187.96066, 192.1619 ,
#            218.67235],
#           [177.88075, 172.66873, 177.72665, ..., 181.99551, 194.82404,
#            221.21213],
#           [173.05408, 176.883  , 177.4325 , ..., 180.85513, 185.97922,
#            191.5753 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.5,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aaudyma',
#    '_id': '500437593515015018_ZTF18aaudyma',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.88201904296875,
#    'obs_days': 2458254.9375926,
#    'seeing': 2.5,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[176.80667, 189.51863, 202.04431, ..., 180.76782, 168.53426,
#            178.4661 ],
#           [180.94232, 180.92712, 192.1698 , ..., 178.02316, 171.7853 ,
#            177.65048],
#           [180.17722, 176.62057, 179.89502, ..., 183.10239, 173.32103,
#            173.24365],
#           ...,
#           [170.63162, 169.36319, 166.74664, ..., 187.96066, 192.1619 ,
#            218.67235],
#           [177.88075, 172.66873, 177.72665, ..., 181.99551, 194.82404,
#            221.21213],
#           [173.05408, 176.883  , 177.4325 , ..., 180.85513, 185.97922,
#            191.5753 ]], dtype=float32),
#    'sky_pixel_values': array([176.80667, 189.51863, 202.04431, ..., 180.85513, 185.97922,
#           191.5753 ], dtype=float32),
#    'filtered_sky_pixel_values': array([176.80667, 183.01234, 177.75476, ..., 181.83821, 182.14917,
#           180.85513], dtype=float32),
#    'sky_value': 175.58885},
#   {'science_stamp': array([[188.53955, 186.57114, 186.2626 , ..., 185.8088 , 175.71788,
#            179.09216],
#           [186.246  , 178.93033, 187.3642 , ..., 182.91464, 183.87402,
#            187.28044],
#           [190.91736, 187.93478, 166.48465, ..., 188.58899, 173.53192,
#            172.55705],
#           ...,
#           [180.70312, 175.94601, 174.94745, ..., 183.96075, 197.90572,
#            200.7682 ],
#           [186.76202, 173.58519, 169.9805 , ..., 180.93631, 183.62106,
#            194.61661],
#           [182.98071, 182.57712, 173.2013 , ..., 178.42618, 184.04701,
#            184.1453 ]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.890000104904175,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aaudyma',
#    '_id': '501420853515015005_ZTF18aaudyma',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.381750106811523,
#    'obs_days': 2458255.9208565,
#    'seeing': 2.890000104904175,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[188.53955, 186.57114, 186.2626 , ..., 185.8088 , 175.71788,
#            179.09216],
#           [186.246  , 178.93033, 187.3642 , ..., 182.91464, 183.87402,
#            187.28044],
#           [190.91736, 187.93478, 166.48465, ..., 188.58899, 173.53192,
#            172.55705],
#           ...,
#           [180.70312, 175.94601, 174.94745, ..., 183.96075, 197.90572,
#            200.7682 ],
#           [186.76202, 173.58519, 169.9805 , ..., 180.93631, 183.62106,
#            194.61661],
#           [182.98071, 182.57712, 173.2013 , ..., 178.42618, 184.04701,
#            184.1453 ]], dtype=float32),
#    'sky_pixel_values': array([188.53955, 186.57114, 186.2626 , ..., 178.42618, 184.04701,
#           184.1453 ], dtype=float32),
#    'filtered_sky_pixel_values': array([177.35492, 176.54855, 175.97795, ..., 178.42618, 184.04701,
#           184.1453 ], dtype=float32),
#    'sky_value': 175.8272}],
#  'Field27': [{'science_stamp': array([[171.73135, 167.58617, 162.29738, ..., 161.8237 , 167.81561,
#            158.89163],
#           [170.00327, 163.62881, 172.96222, ..., 161.66919, 159.49083,
#            166.41928],
#           [169.80191, 174.67758, 169.20016, ..., 163.18486, 157.50558,
#            166.9877 ],
#           ...,
#           [171.38896, 165.31284, 162.185  , ..., 160.84357, 167.38422,
#            168.84096],
#           [173.8447 , 170.63245, 167.80217, ..., 170.2102 , 164.64612,
#            171.5828 ],
#           [164.46545, 162.53177, 166.65108, ..., 176.71957, 168.24997,
#            163.68063]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.309999942779541,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aaudyqv',
#    '_id': '498440403415015032_ZTF18aaudyqv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.814029693603516,
#    'obs_days': 2458252.9404051,
#    'seeing': 3.309999942779541,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[171.73135, 167.58617, 162.29738, ..., 161.8237 , 167.81561,
#            158.89163],
#           [170.00327, 163.62881, 172.96222, ..., 161.66919, 159.49083,
#            166.41928],
#           [169.80191, 174.67758, 169.20016, ..., 163.18486, 157.50558,
#            166.9877 ],
#           ...,
#           [171.38896, 165.31284, 162.185  , ..., 160.84357, 167.38422,
#            168.84096],
#           [173.8447 , 170.63245, 167.80217, ..., 170.2102 , 164.64612,
#            171.5828 ],
#           [164.46545, 162.53177, 166.65108, ..., 176.71957, 168.24997,
#            163.68063]], dtype=float32),
#    'sky_pixel_values': array([171.73135, 167.58617, 162.29738, ..., 176.71957, 168.24997,
#           163.68063], dtype=float32),
#    'filtered_sky_pixel_values': array([171.73135, 167.58617, 162.29738, ..., 163.01834, 168.24997,
#           163.68063], dtype=float32),
#    'sky_value': 165.57509},
#   {'science_stamp': array([[167.64796, 164.99005, 167.19174, ..., 165.92339, 161.27954,
#            158.59409],
#           [165.9896 , 160.28519, 169.60535, ..., 172.30539, 162.89899,
#            163.25449],
#           [161.21558, 172.23499, 165.42636, ..., 162.45435, 172.98502,
#            167.94336],
#           ...,
#           [163.29254, 172.38698, 165.55148, ..., 163.35663, 176.22507,
#            166.75635],
#           [164.17596, 168.2356 , 166.27435, ..., 161.28377, 178.76747,
#            164.9317 ],
#           [165.35052, 163.49738, 166.35352, ..., 163.82782, 167.15309,
#            166.46274]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.2300000190734863,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aaudyqv',
#    '_id': '500437593415015059_ZTF18aaudyqv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.841224670410156,
#    'obs_days': 2458254.9375926,
#    'seeing': 3.2300000190734863,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[167.64796, 164.99005, 167.19174, ..., 165.92339, 161.27954,
#            158.59409],
#           [165.9896 , 160.28519, 169.60535, ..., 172.30539, 162.89899,
#            163.25449],
#           [161.21558, 172.23499, 165.42636, ..., 162.45435, 172.98502,
#            167.94336],
#           ...,
#           [163.29254, 172.38698, 165.55148, ..., 163.35663, 176.22507,
#            166.75635],
#           [164.17596, 168.2356 , 166.27435, ..., 161.28377, 178.76747,
#            164.9317 ],
#           [165.35052, 163.49738, 166.35352, ..., 163.82782, 167.15309,
#            166.46274]], dtype=float32),
#    'sky_pixel_values': array([167.64796, 164.99005, 167.19174, ..., 163.82782, 167.15309,
#           166.46274], dtype=float32),
#    'filtered_sky_pixel_values': array([167.64796, 164.99005, 167.19174, ..., 163.82782, 167.15309,
#           166.46274], dtype=float32),
#    'sky_value': 165.7544},
#   {'science_stamp': array([[169.62756, 176.15712, 164.08228, ..., 170.71857, 163.50943,
#            163.47992],
#           [168.91367, 174.02832, 173.96301, ..., 165.89719, 154.15005,
#            174.40244],
#           [163.27013, 173.49277, 170.13754, ..., 158.37073, 171.34912,
#            166.98805],
#           ...,
#           [171.50769, 157.25195, 158.60428, ..., 168.29051, 167.3733 ,
#            162.0314 ],
#           [161.86258, 168.19229, 171.20374, ..., 168.50055, 165.09634,
#            165.46887],
#           [163.26656, 162.75766, 158.18527, ..., 177.49033, 168.48955,
#            166.10147]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 3.069999933242798,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aaudyqv',
#    '_id': '501420853415015012_ZTF18aaudyqv',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.462379455566406,
#    'obs_days': 2458255.9208565,
#    'seeing': 3.069999933242798,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[169.62756, 176.15712, 164.08228, ..., 170.71857, 163.50943,
#            163.47992],
#           [168.91367, 174.02832, 173.96301, ..., 165.89719, 154.15005,
#            174.40244],
#           [163.27013, 173.49277, 170.13754, ..., 158.37073, 171.34912,
#            166.98805],
#           ...,
#           [171.50769, 157.25195, 158.60428, ..., 168.29051, 167.3733 ,
#            162.0314 ],
#           [161.86258, 168.19229, 171.20374, ..., 168.50055, 165.09634,
#            165.46887],
#           [163.26656, 162.75766, 158.18527, ..., 177.49033, 168.48955,
#            166.10147]], dtype=float32),
#    'sky_pixel_values': array([169.62756, 176.15712, 164.08228, ..., 177.49033, 168.48955,
#           166.10147], dtype=float32),
#    'filtered_sky_pixel_values': array([169.62756, 164.08228, 169.02863, ..., 167.77328, 168.48955,
#           166.10147], dtype=float32),
#    'sky_value': 165.47316}],
#  'Field28': [{'science_stamp': array([[150.74158, 151.09671, 154.74539, ..., 191.48654, 162.78012,
#            160.43382],
#           [157.83994, 155.16559, 159.47137, ..., 159.04428, 174.27371,
#            151.79114],
#           [155.49118, 153.79216, 152.065  , ..., 165.87317, 178.11371,
#            190.36351],
#           ...,
#           [155.16321, 151.9517 , 153.33421, ..., 155.42355, 154.39465,
#            150.64922],
#           [154.49261, 156.16457, 149.2113 , ..., 154.08014, 147.39111,
#            154.57063],
#           [149.88083, 158.15454, 153.43942, ..., 159.60168, 146.83733,
#            149.14865]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.5799999237060547,
#    'mjd': 2458252.9404051,
#    'field': 639,
#    'object_id': 'ZTF18aauekbj',
#    '_id': '498440403615015014_ZTF18aauekbj',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.86139678955078,
#    'obs_days': 2458252.9404051,
#    'seeing': 2.5799999237060547,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[150.74158, 151.09671, 154.74539, ..., 191.48654, 162.78012,
#            160.43382],
#           [157.83994, 155.16559, 159.47137, ..., 159.04428, 174.27371,
#            151.79114],
#           [155.49118, 153.79216, 152.065  , ..., 165.87317, 178.11371,
#            190.36351],
#           ...,
#           [155.16321, 151.9517 , 153.33421, ..., 155.42355, 154.39465,
#            150.64922],
#           [154.49261, 156.16457, 149.2113 , ..., 154.08014, 147.39111,
#            154.57063],
#           [149.88083, 158.15454, 153.43942, ..., 159.60168, 146.83733,
#            149.14865]], dtype=float32),
#    'sky_pixel_values': array([150.74158, 151.09671, 154.74539, ..., 159.60168, 146.83733,
#           149.14865], dtype=float32),
#    'filtered_sky_pixel_values': array([150.74158, 151.09671, 154.74539, ..., 159.60168, 146.83733,
#           149.14865], dtype=float32),
#    'sky_value': 154.42068},
#   {'science_stamp': array([[161.85191, 152.18417, 156.56888, ..., 198.52231, 172.02089,
#            161.0323 ],
#           [155.3547 , 152.74622, 153.66809, ..., 163.67136, 169.98502,
#            155.67679],
#           [159.31256, 144.31596, 157.39722, ..., 160.37187, 172.02911,
#            179.96365],
#           ...,
#           [157.89688, 148.26091, 160.25507, ..., 151.75635, 155.99553,
#            150.7798 ],
#           [161.06064, 157.59366, 155.00304, ..., 155.60358, 153.36519,
#            149.83478],
#           [149.53334, 161.18756, 147.48819, ..., 155.2839 , 146.63286,
#            151.68503]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 1.8200000524520874,
#    'mjd': 2458254.9375926,
#    'field': 639,
#    'object_id': 'ZTF18aauekbj',
#    '_id': '500437593615015011_ZTF18aauekbj',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.810304641723633,
#    'obs_days': 2458254.9375926,
#    'seeing': 1.8200000524520874,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[161.85191, 152.18417, 156.56888, ..., 198.52231, 172.02089,
#            161.0323 ],
#           [155.3547 , 152.74622, 153.66809, ..., 163.67136, 169.98502,
#            155.67679],
#           [159.31256, 144.31596, 157.39722, ..., 160.37187, 172.02911,
#            179.96365],
#           ...,
#           [157.89688, 148.26091, 160.25507, ..., 151.75635, 155.99553,
#            150.7798 ],
#           [161.06064, 157.59366, 155.00304, ..., 155.60358, 153.36519,
#            149.83478],
#           [149.53334, 161.18756, 147.48819, ..., 155.2839 , 146.63286,
#            151.68503]], dtype=float32),
#    'sky_pixel_values': array([161.85191, 152.18417, 156.56888, ..., 155.2839 , 146.63286,
#           151.68503], dtype=float32),
#    'filtered_sky_pixel_values': array([161.85191, 152.18417, 156.56888, ..., 155.2839 , 146.63286,
#           151.68503], dtype=float32),
#    'sky_value': 154.13301},
#   {'science_stamp': array([[169.35669, 160.51242, 156.58469, ..., 185.02124, 183.84074,
#            174.79929],
#           [164.08844, 161.7078 , 150.89069, ..., 171.68066, 168.40988,
#            161.32092],
#           [150.96945, 154.24176, 151.32419, ..., 160.3683 , 160.28831,
#            173.9732 ],
#           ...,
#           [146.86246, 151.79718, 156.08685, ..., 157.98428, 151.72298,
#            159.52148],
#           [141.2432 , 146.27748, 152.02469, ..., 157.04037, 147.76373,
#            152.63629],
#           [148.38153, 155.71068, 148.42595, ..., 149.56319, 149.93594,
#            147.46738]], dtype=float32),
#    'filter': 'g',
#    'fwhm': 2.950000047683716,
#    'mjd': 2458255.9208565,
#    'field': 639,
#    'object_id': 'ZTF18aauekbj',
#    '_id': '501420853615015006_ZTF18aauekbj',
#    'exp_time': 30,
#    'limmag3': None,
#    'limmag5': 20.320520401000977,
#    'obs_days': 2458255.9208565,
#    'seeing': 2.950000047683716,
#    'sky_brightness': None,
#    'zero_point': 1.0,
#    'masked_sky': array([[169.35669, 160.51242, 156.58469, ..., 185.02124, 183.84074,
#            174.79929],
#           [164.08844, 161.7078 , 150.89069, ..., 171.68066, 168.40988,
#            161.32092],
#           [150.96945, 154.24176, 151.32419, ..., 160.3683 , 160.28831,
#            173.9732 ],
#           ...,
#           [146.86246, 151.79718, 156.08685, ..., 157.98428, 151.72298,
#            159.52148],
#           [141.2432 , 146.27748, 152.02469, ..., 157.04037, 147.76373,
#            152.63629],
#           [148.38153, 155.71068, 148.42595, ..., 149.56319, 149.93594,
#            147.46738]], dtype=float32),
#    'sky_pixel_values': array([169.35669, 160.51242, 156.58469, ..., 149.56319, 149.93594,
#           147.46738], dtype=float32),
#    'filtered_sky_pixel_values': array([160.51242, 156.58469, 150.48946, ..., 149.56319, 149.93594,
#           147.46738], dtype=float32),
#    'sky_value': 153.82092}]}

# %%
# Out:
# 108
